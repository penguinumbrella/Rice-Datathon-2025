#      Number of Vehicles Registered at the Same Address     Region  \
# 0                                                   ≥4  Statewide
# 1                                                   ≥4  Statewide
# 2                                                   ≥4  Statewide
# 3                                                   ≥4  Statewide
# 4                                                   ≥4  Statewide
# ...                                                ...        ...
# 7541                                                 3  Statewide
# 7542                                                 2  Statewide
# 7543                                                 3  Statewide
# 7544                                                 2  Statewide
# 7545                                                 1  Statewide
#
#       Vehicle Population
# 0                 316065
# 1                 315986
# 2                 306487
# 3                 284754
# 4                 284153
# ...                  ...
# 7541                   1
# 7542                   1
# 7543                   1
# 7544                   1
# 7545                   1
#
# [7546 rows x 10 columns]

# %%
training = training.rename(columns={
    'Date': 'year',
    'Vehicle Category': 'vehicleCategory',
    'GVWR Class': 'gvwrClass',
    'Fuel Type': 'fuelType',
    "Model Year": "modelYear",
    "Fuel Technology": "fuelTechnology",
    "Electric Mile Range": "electricMileRange",
    "Number of Vehicles Registered at the Same Address": "numVehiclesReg",
    "Vehicle Population:": "vehiclePopulation"
})

training = training.drop(columns=['Region'])

# %%
# Update missing values in Model Year to use mode from Fuel Type, Fuel Technology subcategories
mode_per_group = training.groupby(["fuelType", "fuelTechnology"])['modelYear'].transform(lambda x: pd.Series.mode(x).iloc[0] if not x.mode().empty else x)
training['modelYear'] = training['modelYear'].fillna(mode_per_group)

# %%
# Update unknown values in Electric Mile Range to use mode from Fuel Type, Fuel Technology subcategories
mode_electricMileRange = training.groupby(["year", "vehicleCategory", "fuelType", "fuelTechnology"])['electricMileRange'].transform(lambda x: pd.Series.mode(x).iloc[0] if not x.mode().empty else x)
training['electricMileRange'] = training['electricMileRange'].where(training['electricMileRange'] != 'Unknown', mode_electricMileRange)

# %%
training
# Out:
#        year vehicleCategory       gvwrClass  fuelType  modelYear  \
# 0      2019               P  Not Applicable  Gasoline     2020.0
# 1      2020               P  Not Applicable  Gasoline     2020.0
# 2      2021               P  Not Applicable  Gasoline     2020.0
# 3      2019               P  Not Applicable  Gasoline     2019.0
# 4      2019               P  Not Applicable  Gasoline     2018.0
# ...     ...             ...             ...       ...        ...
# 41048  2019               B  Not Applicable    Diesel     1983.0
# 41049  2019               B  Not Applicable    Diesel     1980.0
# 41050  2019               B  Not Applicable    Diesel     1978.0
# 41051  2019               B  Not Applicable    Diesel     1976.0
# 41052  2019               B  Not Applicable    Diesel     1976.0
#
#       fuelTechnology electricMileRange numVehiclesReg  Vehicle Population
# 0                ICE    Not Applicable             ≥4              395883
# 1                ICE    Not Applicable              1              370954
# 2                ICE    Not Applicable              1              349406
# 3                ICE    Not Applicable             ≥4              348475
# 4                ICE    Not Applicable             ≥4              333296
# ...              ...               ...            ...                 ...
# 41048            ICE    Not Applicable              1                   1
# 41049            ICE    Not Applicable              2                   1
# 41050            ICE    Not Applicable              3                   1
# 41051            ICE    Not Applicable              2                   1
# 41052            ICE    Not Applicable              3                   1
#
# [41053 rows x 9 columns]

# %%
training = pd.get_dummies(training,
                            columns=["gvwrClass", "vehicleCategory", "fuelType", "fuelTechnology", "electricMileRange","numVehiclesReg"],
                            prefix=["gvwrClass", "vehicleCategory", "fuelType", "fuelTech", "electricMileRange", "numVehiclesReg" ],
                            prefix_sep="_")

y_scoring_actual = training['Vehicle Population']

training = training.drop(columns=['Vehicle Population'])
if 'fuelType_Unknown' not in training.columns:
    training['fuelType_Unknown'] = 0

# %%
training
# Out:
#        year  modelYear  gvwrClass_1  gvwrClass_2  gvwrClass_3  gvwrClass_4  \
# 0      2019     2020.0        False        False        False        False
# 1      2020     2020.0        False        False        False        False
# 2      2021     2020.0        False        False        False        False
# 3      2019     2019.0        False        False        False        False
# 4      2019     2018.0        False        False        False        False
# ...     ...        ...          ...          ...          ...          ...
# 41048  2019     1983.0        False        False        False        False
# 41049  2019     1980.0        False        False        False        False
# 41050  2019     1978.0        False        False        False        False
# 41051  2019     1976.0        False        False        False        False
# 41052  2019     1976.0        False        False        False        False
#
#        gvwrClass_5  gvwrClass_6  gvwrClass_7  gvwrClass_8  ...  \
# 0            False        False        False        False  ...
# 1            False        False        False        False  ...
# 2            False        False        False        False  ...
# 3            False        False        False        False  ...
# 4            False        False        False        False  ...
# ...            ...          ...          ...          ...  ...
# 41048        False        False        False        False  ...
# 41049        False        False        False        False  ...
# 41050        False        False        False        False  ...
# 41051        False        False        False        False  ...
# 41052        False        False        False        False  ...
#
#        electricMileRange_0 to 50 miles  electricMileRange_101 to 150 miles  \
# 0                                False                               False
# 1                                False                               False
# 2                                False                               False
# 3                                False                               False
# 4                                False                               False
# ...                                ...                                 ...
# 41048                            False                               False
# 41049                            False                               False
# 41050                            False                               False
# 41051                            False                               False
# 41052                            False                               False
#
#        electricMileRange_51 to 100 miles  electricMileRange_>150 miles  \
# 0                                  False                         False
# 1                                  False                         False
# 2                                  False                         False
# 3                                  False                         False
# 4                                  False                         False
# ...                                  ...                           ...
# 41048                              False                         False
# 41049                              False                         False
# 41050                              False                         False
# 41051                              False                         False
# 41052                              False                         False
#
#        electricMileRange_Not Applicable  numVehiclesReg_1  numVehiclesReg_2  \
# 0                                  True             False             False
# 1                                  True              True             False
# 2                                  True              True             False
# 3                                  True             False             False
# 4                                  True             False             False
# ...                                 ...               ...               ...
# 41048                              True              True             False
# 41049                              True             False              True
# 41050                              True             False             False
# 41051                              True             False              True
# 41052                              True             False             False
#
#        numVehiclesReg_3  numVehiclesReg_Unknown  numVehiclesReg_≥4
# 0                 False                   False               True
# 1                 False                   False              False
# 2                 False                   False              False
# 3                 False                   False               True
# 4                 False                   False               True
# ...                 ...                     ...                ...
# 41048             False                   False              False
# 41049             False                   False              False
# 41050              True                   False              False
# 41051             False                   False              False
# 41052              True                   False              False
#
# [41053 rows x 45 columns]
