# 7542                                                 2  Statewide
# 7543                                                 3  Statewide
# 7544                                                 2  Statewide
# 7545                                                 1  Statewide
#
#       Vehicle Population
# 0                 316065
# 1                 315986
# 2                 306487
# 3                 284754
# 4                 284153
# ...                  ...
# 7541                   1
# 7542                   1
# 7543                   1
# 7544                   1
# 7545                   1
#
# [7546 rows x 10 columns]

# %%
training.groupby(["Date", "Vehicle Category", "Fuel Type", "Fuel Technology"])['Model Year'].agg(lambda x: pd.Series.mode(x).iloc[0])
# Out:
# Date  Vehicle Category  Fuel Type    Fuel Technology
# 2019  B                 Diesel       ICE                1975.0
#                         Electric     BEV                1999.0
#                         Gasoline     ICE                1975.0
#                         Natural Gas  ICE                2007.0
#       BS                Diesel       ICE                1975.0
#                                                          ...
# 2023  T6                Natural Gas  ICE                2018.0
#       T7                Diesel       ICE                1979.0
#                         Electric     BEV                2022.0
#                         Gasoline     ICE                1979.0
#                         Natural Gas  ICE                2009.0
# Name: Model Year, Length: 303, dtype: float64

# %%
# Update missing values in Model Year to use mode from Fuel Type, Fuel Technology subcategories
mode_per_group = training.groupby(["Date", "Vehicle Category", "Fuel Type", "Fuel Technology"])['Model Year'].transform(lambda x: pd.Series.mode(x).iloc[0] if not x.mode().empty else x)
training['Model Year'] = training['Model Year'].fillna(mode_per_group)

# %%
training = training.rename(columns={
    'Date': 'year',
    'Vehicle Category': 'vehicleCategory',
    'GVWR Class': 'gvwrClass',
    'Fuel Type': 'fuelType',
    "Model Year": "modelYear",
    "Fuel Technology": "fuelTechnology",
    "Electric Mile Range": "electricMileRange",
    "Number of Vehicles Registered at the Same Address": "numVehiclesReg",
    "Vehicle Population:": "vehiclePopulation"
})

training = training.drop(columns=['Region'])

'''
training["gvwrClassKN"] = training["gvwrClass"].apply(lambda x: 1 if x == "Unknown" else 0)
training["gvwrClass"] = training["gvwrClass"].replace("Unknown", -1)
training["gvwrClass"] = training["gvwrClass"].replace("Not Applicable", 0)
'''

training["numVehiclesReg"] = training["numVehiclesReg"].apply(lambda x: 4 if x == "≥4" else x)
training["numVehiclesReg"] = training["numVehiclesReg"].replace("Unknown", -1)

training = pd.get_dummies(training,
                            columns=["gvwrClass", "vehicleCategory", "fuelType", "fuelTechnology", "electricMileRange"],
                            prefix=["gvwrClass", "vehicleCategory", "fuelType", "fuelTech", "electricRange"],
                            prefix_sep="_")

y_scoring_actual = training['Vehicle Population'] 

training = training.drop(columns=['Vehicle Population'])
if 'fuelType_Unknown' not in training.columns:
    training['fuelType_Unknown'] = 0
# Out:
# C:\Users\ginap\AppData\Local\Temp\ipykernel_17548\193154782.py:22: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   training["numVehiclesReg"] = training["numVehiclesReg"].replace("Unknown", -1)

# %%
training
# Out:
#        year  modelYear  numVehiclesReg  gvwrClass_1  gvwrClass_2  gvwrClass_3  \
# 0      2019     2020.0               4        False        False        False
# 1      2020     2020.0               1        False        False        False
# 2      2021     2020.0               1        False        False        False
# 3      2019     2019.0               4        False        False        False
# 4      2019     2018.0               4        False        False        False
# ...     ...        ...             ...          ...          ...          ...
# 41048  2019     1983.0               1        False        False        False
# 41049  2019     1980.0               2        False        False        False
# 41050  2019     1978.0               3        False        False        False
# 41051  2019     1976.0               2        False        False        False
# 41052  2019     1976.0               3        False        False        False
#
#        gvwrClass_4  gvwrClass_5  gvwrClass_6  gvwrClass_7  ...  fuelTech_BEV  \
# 0            False        False        False        False  ...         False
# 1            False        False        False        False  ...         False
# 2            False        False        False        False  ...         False
# 3            False        False        False        False  ...         False
# 4            False        False        False        False  ...         False
# ...            ...          ...          ...          ...  ...           ...
# 41048        False        False        False        False  ...         False
# 41049        False        False        False        False  ...         False
# 41050        False        False        False        False  ...         False
# 41051        False        False        False        False  ...         False
# 41052        False        False        False        False  ...         False
#
#        fuelTech_FCEV  fuelTech_ICE  fuelTech_PHEV  \
# 0              False          True          False
# 1              False          True          False
# 2              False          True          False
# 3              False          True          False
# 4              False          True          False
# ...              ...           ...            ...
# 41048          False          True          False
# 41049          False          True          False
# 41050          False          True          False
# 41051          False          True          False
# 41052          False          True          False
#
#        electricRange_0 to 50 miles  electricRange_101 to 150 miles  \
# 0                            False                           False
# 1                            False                           False
# 2                            False                           False
# 3                            False                           False
# 4                            False                           False
# ...                            ...                             ...
# 41048                        False                           False
# 41049                        False                           False
# 41050                        False                           False
# 41051                        False                           False
# 41052                        False                           False
#
#        electricRange_51 to 100 miles  electricRange_>150 miles  \
# 0                              False                     False
# 1                              False                     False
# 2                              False                     False
# 3                              False                     False
# 4                              False                     False
# ...                              ...                       ...
# 41048                          False                     False
# 41049                          False                     False
# 41050                          False                     False
# 41051                          False                     False
# 41052                          False                     False
#
#        electricRange_Not Applicable  electricRange_Unknown
# 0                              True                  False
# 1                              True                  False
# 2                              True                  False
# 3                              True                  False
# 4                              True                  False
# ...                             ...                    ...
# 41048                          True                  False
# 41049                          True                  False
# 41050                          True                  False
# 41051                          True                  False
# 41052                          True                  False
#
# [41053 rows x 42 columns]

# %%
californiaUtilityData = pd.read_excel("californiaUtilityData.xlsx")
californiaUtilityData
# Out:
#     year  avgGasPerThermUSD  avgElecKWHUSD  avgLowSulfurDieselUSDPerGallon  \
# 0   1996           0.584667       0.127667                        0.780333
# 1   1997           0.680333       0.127000                        0.678333
# 2   1998           0.672667       0.113417                        0.485917
# 3   1999           0.709250       0.115000                        0.631000
# 4   2000           0.880000       0.115000                        0.977917
# 5   2001           1.073750       0.148417                        0.816000
# 6   2002           0.729167       0.160250                        0.749917
# 7   2003           1.002917       0.156000                        0.914667
# 8   2004           1.001667       0.144833                        1.317667
# 9   2005           1.327000       0.149417                        1.789083
# 10  2006           1.332250       0.184750                        2.082583
# 11  2007           1.387750       0.188833                        2.248167
# 12  2008           1.538750       0.190667                        2.908417
# 13  2009           1.161000       0.209667                        1.696417
# 14  2010           1.236667       0.218750                        2.204083
# 15  2011           1.295583       0.213000                        3.048750
# 16  2012           1.236083       0.213167                        3.106083
# 17  2013           1.235750       0.221417                        3.012750
# 18  2014           1.424667       0.219833                        2.785750
# 19  2015           1.454917       0.218583                        1.660333
# 20  2016           1.428000       0.194833                        1.386667
# 21  2017           1.486750       0.204250                        1.706417
# 22  2018           1.449750       0.209750                        2.127833
# 23  2019           1.486333       0.217333                        2.008417
# 24  2020           1.615583       0.234917                        1.306917
# 25  2021           1.797500       0.256000                        2.099083
# 26  2022           2.259333       0.303250                        3.524667
# 27  2023           2.089083       0.338500                        2.926000
# 28  2024           2.301333       0.396333                        2.440250
#
#     avgPriceGasolineUnleadedRegularUSDPerGallon
# 0                                      1.409778
# 1                                      1.382250
# 2                                      1.239083
# 3                                      1.443583
# 4                                      1.765417
# 5                                      1.733250
# 6                                      1.526333
# 7                                      1.866750
# 8                                      2.113667
# 9                                      2.469583
# 10                                     2.767583
# 11                                     3.094500
# 12                                     3.521083
# 13                                     2.646750
# 14                                     3.067667
# 15                                     3.788833
# 16                                     4.018750
# 17                                     3.859167
# 18                                     3.734000
# 19                                     3.075833
# 20                                     2.711000
# 21                                     3.033500
# 22                                     3.641833
# 23                                     3.705417
# 24                                     3.118000
# 25                                     4.189333
# 26                                     5.550750
# 27                                     4.979583
# 28                                     4.863500

# %%
californiaUtilityData = californiaUtilityData.rename(columns={"year": "modelYear"})

# %%
californiaUtilityData
# Out:
#     modelYear  avgGasPerThermUSD  avgElecKWHUSD  \
# 0        1996           0.584667       0.127667
# 1        1997           0.680333       0.127000
# 2        1998           0.672667       0.113417
# 3        1999           0.709250       0.115000
# 4        2000           0.880000       0.115000
# 5        2001           1.073750       0.148417
# 6        2002           0.729167       0.160250
# 7        2003           1.002917       0.156000
# 8        2004           1.001667       0.144833
# 9        2005           1.327000       0.149417
# 10       2006           1.332250       0.184750
# 11       2007           1.387750       0.188833
# 12       2008           1.538750       0.190667
# 13       2009           1.161000       0.209667
# 14       2010           1.236667       0.218750
# 15       2011           1.295583       0.213000
# 16       2012           1.236083       0.213167
# 17       2013           1.235750       0.221417
# 18       2014           1.424667       0.219833
# 19       2015           1.454917       0.218583
# 20       2016           1.428000       0.194833
# 21       2017           1.486750       0.204250
# 22       2018           1.449750       0.209750
# 23       2019           1.486333       0.217333
# 24       2020           1.615583       0.234917
# 25       2021           1.797500       0.256000
# 26       2022           2.259333       0.303250
# 27       2023           2.089083       0.338500
# 28       2024           2.301333       0.396333
#
#     avgLowSulfurDieselUSDPerGallon  \
# 0                         0.780333
# 1                         0.678333
# 2                         0.485917
# 3                         0.631000
# 4                         0.977917
# 5                         0.816000
# 6                         0.749917
# 7                         0.914667
# 8                         1.317667
# 9                         1.789083
# 10                        2.082583
# 11                        2.248167
# 12                        2.908417
# 13                        1.696417
# 14                        2.204083
# 15                        3.048750
# 16                        3.106083
# 17                        3.012750
# 18                        2.785750
# 19                        1.660333
# 20                        1.386667
# 21                        1.706417
# 22                        2.127833
# 23                        2.008417
# 24                        1.306917
# 25                        2.099083
# 26                        3.524667
# 27                        2.926000
# 28                        2.440250
#
#     avgPriceGasolineUnleadedRegularUSDPerGallon
# 0                                      1.409778
# 1                                      1.382250
# 2                                      1.239083
# 3                                      1.443583
# 4                                      1.765417
# 5                                      1.733250
# 6                                      1.526333
# 7                                      1.866750
# 8                                      2.113667
# 9                                      2.469583
# 10                                     2.767583
# 11                                     3.094500
# 12                                     3.521083
# 13                                     2.646750
# 14                                     3.067667
# 15                                     3.788833
# 16                                     4.018750
# 17                                     3.859167
# 18                                     3.734000
# 19                                     3.075833
# 20                                     2.711000
# 21                                     3.033500
# 22                                     3.641833
# 23                                     3.705417
# 24                                     3.118000
# 25                                     4.189333
# 26                                     5.550750
# 27                                     4.979583
# 28                                     4.863500

# %%
trainingWUtilData = pd.merge(training, californiaUtilityData, on="modelYear", )

# %%
trainingWUtilData
# Out:
#        year  modelYear  numVehiclesReg  gvwrClass_1  gvwrClass_2  gvwrClass_3  \
# 0      2019     2020.0               4        False        False        False
# 1      2020     2020.0               1        False        False        False
# 2      2021     2020.0               1        False        False        False
# 3      2019     2019.0               4        False        False        False
# 4      2019     2018.0               4        False        False        False
# ...     ...        ...             ...          ...          ...          ...
# 26796  2019     2017.0               3        False        False        False
# 26797  2019     2016.0               3        False        False        False
# 26798  2019     2009.0               2        False        False        False
# 26799  2019     2008.0               3        False        False        False
# 26800  2019     1997.0               3        False        False        False
#
#        gvwrClass_4  gvwrClass_5  gvwrClass_6  gvwrClass_7  ...  \
# 0            False        False        False        False  ...
# 1            False        False        False        False  ...
# 2            False        False        False        False  ...
# 3            False        False        False        False  ...
# 4            False        False        False        False  ...
# ...            ...          ...          ...          ...  ...
# 26796        False        False        False        False  ...
# 26797        False        False        False        False  ...
# 26798        False        False        False        False  ...
# 26799        False        False        False        False  ...
# 26800        False        False        False        False  ...
#
#        electricRange_0 to 50 miles  electricRange_101 to 150 miles  \
# 0                            False                           False
# 1                            False                           False
# 2                            False                           False
# 3                            False                           False
# 4                            False                           False
# ...                            ...                             ...
# 26796                        False                           False
# 26797                        False                           False
# 26798                        False                           False
# 26799                        False                           False
# 26800                        False                           False
#
#        electricRange_51 to 100 miles  electricRange_>150 miles  \
# 0                              False                     False
# 1                              False                     False
# 2                              False                     False
# 3                              False                     False
# 4                              False                     False
# ...                              ...                       ...
# 26796                          False                     False
# 26797                          False                     False
# 26798                          False                     False
# 26799                          False                     False
# 26800                          False                     False
#
#        electricRange_Not Applicable  electricRange_Unknown  avgGasPerThermUSD  \
# 0                              True                  False           1.615583
# 1                              True                  False           1.615583
# 2                              True                  False           1.615583
# 3                              True                  False           1.486333
# 4                              True                  False           1.449750
# ...                             ...                    ...                ...
# 26796                          True                  False           1.486750
# 26797                          True                  False           1.428000
# 26798                          True                  False           1.161000
# 26799                          True                  False           1.538750
# 26800                          True                  False           0.680333
#
#        avgElecKWHUSD  avgLowSulfurDieselUSDPerGallon  \
# 0           0.234917                        1.306917
# 1           0.234917                        1.306917
# 2           0.234917                        1.306917
# 3           0.217333                        2.008417
# 4           0.209750                        2.127833
# ...              ...                             ...
# 26796       0.204250                        1.706417
# 26797       0.194833                        1.386667
# 26798       0.209667                        1.696417
# 26799       0.190667                        2.908417
# 26800       0.127000                        0.678333
#
#        avgPriceGasolineUnleadedRegularUSDPerGallon
# 0                                         3.118000
# 1                                         3.118000
# 2                                         3.118000
# 3                                         3.705417
# 4                                         3.641833
# ...                                            ...
# 26796                                     3.033500
# 26797                                     2.711000
# 26798                                     2.646750
# 26799                                     3.521083
# 26800                                     1.382250
#
# [26801 rows x 46 columns]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
